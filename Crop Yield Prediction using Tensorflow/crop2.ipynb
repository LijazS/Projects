# %% [markdown]
# LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf

# %% [markdown]
# DATA

# %%
df = pd.read_csv('C:/Users/lijaz/Desktop/DATA/Crop/crop_yield.csv')

# %%
df.head()
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield
# 0           2051.4  7024878.38   22882.34     0.796087
# 1           2051.4   631643.29    2057.47     0.710435
# 2           2051.4    75755.32     246.76     0.238333
# 3           2051.4  1870661.52    6093.36  5238.051739
# 4           2051.4   165500.63     539.09     0.420909

# %%
df['Crop'].unique()
# Out:
# array(['Arecanut', 'Arhar/Tur', 'Castor seed', 'Coconut ', 'Cotton(lint)',
#        'Dry chillies', 'Gram', 'Jute', 'Linseed', 'Maize', 'Mesta',
#        'Niger seed', 'Onion', 'Other  Rabi pulses', 'Potato',
#        'Rapeseed &Mustard', 'Rice', 'Sesamum', 'Small millets',
#        'Sugarcane', 'Sweet potato', 'Tapioca', 'Tobacco', 'Turmeric',
#        'Wheat', 'Bajra', 'Black pepper', 'Cardamom', 'Coriander',
#        'Garlic', 'Ginger', 'Groundnut', 'Horse-gram', 'Jowar', 'Ragi',
#        'Cashewnut', 'Banana', 'Soyabean', 'Barley', 'Khesari', 'Masoor',
#        'Moong(Green Gram)', 'Other Kharif pulses', 'Safflower',
#        'Sannhamp', 'Sunflower', 'Urad', 'Peas & beans (Pulses)',
#        'other oilseeds', 'Other Cereals', 'Cowpea(Lobia)',
#        'Oilseeds total', 'Guar seed', 'Other Summer Pulses', 'Moth'],
#       dtype=object)

# %% [markdown]
# SELECTING A CROP

# %%
df = df[df['Crop']=='Rice']
df.head()
# Out:
#     Crop  Crop_Year       Season      State       Area  Production  \
# 16  Rice       1997  Autumn           Assam   607358.0      398311
# 17  Rice       1997  Summer           Assam   174974.0      209623
# 18  Rice       1997  Winter           Assam  1743321.0     1647296
# 51  Rice       1997  Kharif       Karnataka  1031530.0     2340493
# 52  Rice       1997  Rabi         Karnataka    53889.0      109350
#
#     Annual_Rainfall    Fertilizer  Pesticide     Yield
# 16           2051.4  5.780226e+07  188280.98  0.780870
# 17           2051.4  1.665228e+07   54241.94  1.060435
# 18           2051.4  1.659119e+08  540429.51  0.941304
# 51           1266.7  9.817071e+07  319774.30  2.233500
# 52           1266.7  5.128616e+06   16705.59  2.073846

# %% [markdown]
# CHECKING FOR NULL AND DUPLICATES

# %%
df.isna().sum()
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# NO NULL OR DUPLICATES FOUND

# %% [markdown]
# Filtering

# %%
needed = ['Fertilizer', 'Pesticide', 'Yield']
bf = df[needed]

# %% [markdown]
# PLOTS :

# %% [markdown]
# GROWTH BY YEAR

# %% [markdown]
# OF KERALA

# %%
calc = df.groupby(['State','Crop_Year'])['Yield'].sum().reset_index()
kerala = calc[calc['State'] == 'Kerala']
plt.figure(figsize=(10,6))
plt.title('Growth of Kerala by Year')

plt.plot(kerala['Crop_Year'],kerala['Yield'])

# %% [markdown]
# OF KARNATAKA

# %%
Kn = calc[calc['State'] == 'Karnataka']

plt.figure(figsize=(10,6))
plt.title('Growth of Karnataka by Year')
plt.plot(Kn['Crop_Year'],Kn['Yield'])

# %% [markdown]
# PAIRPLOT

# %%
ned = ['Crop','Season','State','Crop_Year','Area','Annual_Rainfall','Fertilizer','Pesticide','Yield']
sf = df[ned]
sns.pairplot(sf)
plt.savefig('PairPlot.png')

# %%
plt.scatter(df['Annual_Rainfall'],df['Yield'])
plt.title('Relation btw Rainfall and yield')
plt.show()

# %% [markdown]
# OBSERVATIONS:

# %% [markdown]
# IDENTIFIED RELATIONS BETWEEN VARIABLES

# %% [markdown]
# identified various relationships between variables. However, many of these relationships were only minuscule, indicating weak or subtle connections.
#  Due to the limited strength of the relationships identified, I implemented a deep learning model using TensorFlow.

# %% [markdown]
# OUTLIER DETECTION :

# %%
qf = df['Area']
plt.figure(figsize=(10, 6))
plt.boxplot(qf, vert=False)

plt.title('BOXPLOT TO DETECT OUTLIERS IN AREA')
plt.show()

# %%
qf = df['Fertilizer']
plt.figure(figsize=(10, 6))
plt.boxplot(qf, vert=False)

plt.title('BOXPLOT TO DETECT OUTLIERS IN FERTILIZER')
plt.show()

# %%
qf = df['Pesticide']
plt.figure(figsize=(10, 6))
plt.boxplot(qf, vert=False)

plt.title('BOXPLOT TO DETECT OUTLIERS IN PESTICIDE')
plt.show()

# %%
qf = df['Annual_Rainfall']
plt.figure(figsize=(10, 6))
plt.boxplot(qf, vert=False)

plt.title('BOXPLOT TO DETECT OUTLIERS IN ANNUAL RAINFALL')
plt.show()

# %% [markdown]
# IDENTIFIED OUTLIERS IN VARIOUS VARIABLES

# %% [markdown]
# OUTLIER REMOVING:

# %% [markdown]
# USING STD METHOD

# %%
df.head()
# Out:
#     Crop  Crop_Year       Season      State       Area  Production  \
# 16  Rice       1997  Autumn           Assam   607358.0      398311
# 17  Rice       1997  Summer           Assam   174974.0      209623
# 18  Rice       1997  Winter           Assam  1743321.0     1647296
# 51  Rice       1997  Kharif       Karnataka  1031530.0     2340493
# 52  Rice       1997  Rabi         Karnataka    53889.0      109350
#
#     Annual_Rainfall    Fertilizer  Pesticide     Yield
# 16           2051.4  5.780226e+07  188280.98  0.780870
# 17           2051.4  1.665228e+07   54241.94  1.060435
# 18           2051.4  1.659119e+08  540429.51  0.941304
# 51           1266.7  9.817071e+07  319774.30  2.233500
# 52           1266.7  5.128616e+06   16705.59  2.073846

# %%
mean = df['Fertilizer'].mean()
std = df['Fertilizer'].std()

upper = mean + 2 * std
lower = mean - 2 * std

df = df[(df['Fertilizer'] >= lower) & (df['Fertilizer'] <= upper)]

# %%
df.shape
# Out:
# (1120, 10)

# %%
mean = df['Pesticide'].mean()
std = df['Pesticide'].std()

upper = mean + 2 * std
lower = mean - 2 * std

df = df[(df['Pesticide'] >= lower) & (df['Pesticide'] <= upper)]

# %%
df.shape
# Out:
# (1051, 10)

# %% [markdown]
# Std scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()



df['Area_scaled'] = scaler.fit_transform(df[['Area']])
df['Production_scaled'] = scaler.fit_transform(df[['Production']])
df['Annual_Rainfall_scaled'] = scaler.fit_transform(df[['Annual_Rainfall']])
df['Fertilizer_scaled'] = scaler.fit_transform(df[['Fertilizer']])
df['Pesticide_scaled'] = scaler.fit_transform(df[['Pesticide']])
df['Yield_scaled'] = scaler.fit_transform(df[['Yield']])

# %%
needed = ['Crop','Season','State','Crop_Year','Area_scaled','Area','Production_scaled','Annual_Rainfall_scaled','Annual_Rainfall','Fertilizer','Fertilizer_scaled','Yield_scaled','Yield','Pesticide','Pesticide_scaled']
pf = df[needed]

# %%
from sklearn.preprocessing import LabelEncoder

li = LabelEncoder()

pf['Crop_encoded'] = li.fit_transform(pf['Crop'])
pf['season_en'] = li.fit_transform(pf['Season'])
pf['state_en'] = li.fit_transform(pf['State'])

# %%
pf.head()
# Out:
#     Crop       Season      State  Crop_Year  Area_scaled       Area  \
# 16  Rice  Autumn           Assam       1997     0.296760   607358.0
# 17  Rice  Summer           Assam       1997    -0.417892   174974.0
# 18  Rice  Winter           Assam       1997     2.174300  1743321.0
# 51  Rice  Kharif       Karnataka       1997     0.997839  1031530.0
# 52  Rice  Rabi         Karnataka       1997    -0.618024    53889.0
#
#     Production_scaled  Annual_Rainfall_scaled  Annual_Rainfall    Fertilizer  \
# 16          -0.367090                0.326826           2051.4  5.780226e+07
# 17          -0.480842                0.326826           2051.4  1.665228e+07
# 18           0.385865                0.326826           2051.4  1.659119e+08
# 51           0.803762               -0.484453           1266.7  9.817071e+07
# 52          -0.541292               -0.484453           1266.7  5.128616e+06
#
#     Fertilizer_scaled  Yield_scaled     Yield  Pesticide  Pesticide_scaled  \
# 16           0.006217     -1.801357  0.780870  188280.98          0.518682
# 17          -0.494163     -1.452173  1.060435   54241.94         -0.363076
# 18           1.320821     -1.600970  0.941304  540429.51          2.835247
# 51           0.497094      0.013012  2.233500  319774.30          1.383694
# 52          -0.634290     -0.186399  2.073846   16705.59         -0.610005
#
#     Crop_encoded  season_en  state_en
# 16             0          0         2
# 17             0          3         2
# 18             0          5         2
# 51             0          1        11
# 52             0          2        11

# %% [markdown]
# HEATMAP

# %%
ned = ['Crop_Year','Area','Annual_Rainfall','Fertilizer','Pesticide','Yield']
sf = df[ned]
sf['Season'] = pf['season_en']
sf['State'] = pf['state_en']

sf.head()
# Out:
# C:\Users\lijaz\AppData\Local\Temp\ipykernel_10308\272658216.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sf['Season'] = pf['season_en']
# C:\Users\lijaz\AppData\Local\Temp\ipykernel_10308\272658216.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sf['State'] = pf['state_en']
#     Crop_Year       Area  Annual_Rainfall    Fertilizer  Pesticide     Yield  \
# 16       1997   607358.0           2051.4  5.780226e+07  188280.98  0.780870
# 17       1997   174974.0           2051.4  1.665228e+07   54241.94  1.060435
# 18       1997  1743321.0           2051.4  1.659119e+08  540429.51  0.941304
# 51       1997  1031530.0           1266.7  9.817071e+07  319774.30  2.233500
# 52       1997    53889.0           1266.7  5.128616e+06   16705.59  2.073846
#
#     Season  State
# 16       0      2
# 17       3      2
# 18       5      2
# 51       1     11
# 52       2     11

# %%
correlation_matrix = sf.corr()


plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %% [markdown]
# Train test split

# %%
from sklearn.model_selection import train_test_split

x = pf[['state_en','season_en','Area_scaled','Annual_Rainfall','Fertilizer_scaled','Pesticide_scaled']]
y = pf[['Yield']]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# TENSORFLOW

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, input_shape=(x_train.shape[1],), activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')  
])
# Out:
# c:\Users\lijaz\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='mean_squared_error',
              metrics=['mean_absolute_error','mean_absolute_percentage_error'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 64)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,073 (12.00 KB)
#  Trainable params: 3,073 (12.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# TRAINING

# %%
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2618.1875 - mean_absolute_error: 35.0130 - mean_absolute_percentage_error: 1888.4205 - val_loss: 265.8645 - val_mean_absolute_error: 14.7583 - val_mean_absolute_percentage_error: 757.3419
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 675.1302 - mean_absolute_error: 17.9844 - mean_absolute_percentage_error: 1063.0657 - val_loss: 10.1527 - val_mean_absolute_error: 3.0704 - val_mean_absolute_percentage_error: 147.5566
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 400.1141 - mean_absolute_error: 12.7632 - mean_absolute_percentage_error: 683.1678 - val_loss: 2.0721 - val_mean_absolute_error: 1.1502 - val_mean_absolute_percentage_error: 49.5612
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 180.0307 - mean_absolute_error: 9.4427 - mean_absolute_percentage_error: 677.3074 - val_loss: 1.8385 - val_mean_absolute_error: 1.0672 - val_mean_absolute_percentage_error: 47.1998
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 164.0856 - mean_absolute_error: 8.9198 - mean_absolute_percentage_error: 495.3516 - val_loss: 1.6879 - val_mean_absolute_error: 0.9957 - val_mean_absolute_percentage_error: 43.0724
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 135.4239 - mean_absolute_error: 7.5373 - mean_absolute_percentage_error: 424.6680 - val_loss: 3.8340 - val_mean_absolute_error: 1.5147 - val_mean_absolute_percentage_error: 79.7370
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 134.6311 - mean_absolute_error: 6.6578 - mean_absolute_percentage_error: 380.4998 - val_loss: 3.2076 - val_mean_absolute_error: 1.3924 - val_mean_absolute_percentage_error: 72.4045
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 124.9804 - mean_absolute_error: 6.0985 - mean_absolute_percentage_error: 329.2273 - val_loss: 4.8902 - val_mean_absolute_error: 1.6839 - val_mean_absolute_percentage_error: 89.3549
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 110.5856 - mean_absolute_error: 6.2292 - mean_absolute_percentage_error: 329.1271 - val_loss: 4.6982 - val_mean_absolute_error: 1.6538 - val_mean_absolute_percentage_error: 87.5940
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 76.4340 - mean_absolute_error: 5.4453 - mean_absolute_percentage_error: 285.2923 - val_loss: 6.1852 - val_mean_absolute_error: 1.8895 - val_mean_absolute_percentage_error: 101.5742
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.1200 - mean_absolute_error: 4.4834 - mean_absolute_percentage_error: 283.3071 - val_loss: 2.6333 - val_mean_absolute_error: 1.2690 - val_mean_absolute_percentage_error: 64.9268
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.3100 - mean_absolute_error: 4.3651 - mean_absolute_percentage_error: 232.9063 - val_loss: 1.7518 - val_mean_absolute_error: 1.0474 - val_mean_absolute_percentage_error: 49.9677
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.1835 - mean_absolute_error: 4.1463 - mean_absolute_percentage_error: 223.4781 - val_loss: 1.9340 - val_mean_absolute_error: 1.1044 - val_mean_absolute_percentage_error: 54.0065
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 62.3231 - mean_absolute_error: 4.0239 - mean_absolute_percentage_error: 207.8560 - val_loss: 3.2766 - val_mean_absolute_error: 1.4055 - val_mean_absolute_percentage_error: 73.4437
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 61.1500 - mean_absolute_error: 3.7706 - mean_absolute_percentage_error: 217.3938 - val_loss: 2.0651 - val_mean_absolute_error: 1.1392 - val_mean_absolute_percentage_error: 56.2895
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.5424 - mean_absolute_error: 3.7543 - mean_absolute_percentage_error: 198.9615 - val_loss: 1.6749 - val_mean_absolute_error: 1.0218 - val_mean_absolute_percentage_error: 47.9494
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 54.0512 - mean_absolute_error: 3.8022 - mean_absolute_percentage_error: 404.9418 - val_loss: 1.7958 - val_mean_absolute_error: 1.0634 - val_mean_absolute_percentage_error: 50.8722
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 27.2904 - mean_absolute_error: 3.3971 - mean_absolute_percentage_error: 187.4032 - val_loss: 1.7916 - val_mean_absolute_error: 1.0626 - val_mean_absolute_percentage_error: 50.9941
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.8481 - mean_absolute_error: 3.0988 - mean_absolute_percentage_error: 157.6546 - val_loss: 1.9731 - val_mean_absolute_error: 1.1161 - val_mean_absolute_percentage_error: 54.9849
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.3561 - mean_absolute_error: 2.9875 - mean_absolute_percentage_error: 147.1722 - val_loss: 1.5484 - val_mean_absolute_error: 0.9720 - val_mean_absolute_percentage_error: 44.6223
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.0887 - mean_absolute_error: 2.7961 - mean_absolute_percentage_error: 155.6890 - val_loss: 1.6454 - val_mean_absolute_error: 1.0146 - val_mean_absolute_percentage_error: 48.0611
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.1234 - mean_absolute_error: 2.9766 - mean_absolute_percentage_error: 170.3356 - val_loss: 1.5571 - val_mean_absolute_error: 0.9785 - val_mean_absolute_percentage_error: 45.3469
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.8421 - mean_absolute_error: 2.7923 - mean_absolute_percentage_error: 139.6867 - val_loss: 2.0534 - val_mean_absolute_error: 1.1364 - val_mean_absolute_percentage_error: 56.8496
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.4150 - mean_absolute_error: 2.7833 - mean_absolute_percentage_error: 156.5679 - val_loss: 1.5730 - val_mean_absolute_error: 0.9885 - val_mean_absolute_percentage_error: 46.3777
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.4020 - mean_absolute_error: 2.5297 - mean_absolute_percentage_error: 128.7315 - val_loss: 1.4837 - val_mean_absolute_error: 0.9367 - val_mean_absolute_percentage_error: 41.6167
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.8813 - mean_absolute_error: 2.6789 - mean_absolute_percentage_error: 136.7922 - val_loss: 1.6284 - val_mean_absolute_error: 1.0122 - val_mean_absolute_percentage_error: 48.3559
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.2512 - mean_absolute_error: 2.3622 - mean_absolute_percentage_error: 124.9542 - val_loss: 1.5225 - val_mean_absolute_error: 0.9682 - val_mean_absolute_percentage_error: 44.8712
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8231 - mean_absolute_error: 2.1538 - mean_absolute_percentage_error: 125.5591 - val_loss: 1.6727 - val_mean_absolute_error: 1.0290 - val_mean_absolute_percentage_error: 49.5864
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.6149 - mean_absolute_error: 2.2016 - mean_absolute_percentage_error: 154.6344 - val_loss: 1.8029 - val_mean_absolute_error: 1.0710 - val_mean_absolute_percentage_error: 52.6795
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.5740 - mean_absolute_error: 2.1795 - mean_absolute_percentage_error: 121.4757 - val_loss: 1.7275 - val_mean_absolute_error: 1.0485 - val_mean_absolute_percentage_error: 51.1793
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0415 - mean_absolute_error: 1.9940 - mean_absolute_percentage_error: 102.6057 - val_loss: 1.4565 - val_mean_absolute_error: 0.9246 - val_mean_absolute_percentage_error: 40.5006
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0780 - mean_absolute_error: 2.1297 - mean_absolute_percentage_error: 116.9776 - val_loss: 1.4556 - val_mean_absolute_error: 0.9442 - val_mean_absolute_percentage_error: 43.6369
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2393 - mean_absolute_error: 2.0431 - mean_absolute_percentage_error: 104.8131 - val_loss: 1.5447 - val_mean_absolute_error: 0.9574 - val_mean_absolute_percentage_error: 40.9139
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2800 - mean_absolute_error: 1.9500 - mean_absolute_percentage_error: 95.9865 - val_loss: 1.4158 - val_mean_absolute_error: 0.9256 - val_mean_absolute_percentage_error: 42.2755
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9512 - mean_absolute_error: 2.0396 - mean_absolute_percentage_error: 114.9503 - val_loss: 1.4320 - val_mean_absolute_error: 0.9376 - val_mean_absolute_percentage_error: 43.5145
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9605 - mean_absolute_error: 1.8183 - mean_absolute_percentage_error: 85.5453 - val_loss: 1.3871 - val_mean_absolute_error: 0.9102 - val_mean_absolute_percentage_error: 41.1096
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2395 - mean_absolute_error: 1.8913 - mean_absolute_percentage_error: 90.3216 - val_loss: 1.3971 - val_mean_absolute_error: 0.9231 - val_mean_absolute_percentage_error: 42.6136
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.3819 - mean_absolute_error: 1.9959 - mean_absolute_percentage_error: 145.2583 - val_loss: 1.3894 - val_mean_absolute_error: 0.9219 - val_mean_absolute_percentage_error: 42.7554
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.3839 - mean_absolute_error: 2.0043 - mean_absolute_percentage_error: 105.3245 - val_loss: 1.3685 - val_mean_absolute_error: 0.9128 - val_mean_absolute_percentage_error: 42.1957
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3552 - mean_absolute_error: 1.7391 - mean_absolute_percentage_error: 90.0507 - val_loss: 1.3433 - val_mean_absolute_error: 0.8914 - val_mean_absolute_percentage_error: 40.0647
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8397 - mean_absolute_error: 1.7299 - mean_absolute_percentage_error: 91.1046 - val_loss: 1.3513 - val_mean_absolute_error: 0.8877 - val_mean_absolute_percentage_error: 39.1379
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7657 - mean_absolute_error: 1.6029 - mean_absolute_percentage_error: 89.3927 - val_loss: 1.3292 - val_mean_absolute_error: 0.8856 - val_mean_absolute_percentage_error: 39.6930
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7852 - mean_absolute_error: 1.5790 - mean_absolute_percentage_error: 87.8961 - val_loss: 1.3431 - val_mean_absolute_error: 0.8845 - val_mean_absolute_percentage_error: 38.9221
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3764 - mean_absolute_error: 1.7760 - mean_absolute_percentage_error: 85.4166 - val_loss: 1.3260 - val_mean_absolute_error: 0.8975 - val_mean_absolute_percentage_error: 41.4911
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0688 - mean_absolute_error: 1.7238 - mean_absolute_percentage_error: 94.3073 - val_loss: 1.3234 - val_mean_absolute_error: 0.8999 - val_mean_absolute_percentage_error: 41.9225
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0394 - mean_absolute_error: 1.4915 - mean_absolute_percentage_error: 69.6237 - val_loss: 1.3283 - val_mean_absolute_error: 0.9053 - val_mean_absolute_percentage_error: 42.5143
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1513 - mean_absolute_error: 1.6296 - mean_absolute_percentage_error: 129.7612 - val_loss: 1.2980 - val_mean_absolute_error: 0.8886 - val_mean_absolute_percentage_error: 41.1934
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3471 - mean_absolute_error: 1.5266 - mean_absolute_percentage_error: 70.0410 - val_loss: 1.2937 - val_mean_absolute_error: 0.8892 - val_mean_absolute_percentage_error: 41.4197
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0989 - mean_absolute_error: 1.4757 - mean_absolute_percentage_error: 74.4812 - val_loss: 1.2766 - val_mean_absolute_error: 0.8815 - val_mean_absolute_percentage_error: 40.9556
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5627 - mean_absolute_error: 1.5768 - mean_absolute_percentage_error: 79.5882 - val_loss: 1.3000 - val_mean_absolute_error: 0.8995 - val_mean_absolute_percentage_error: 42.6540
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8281 - mean_absolute_error: 1.4978 - mean_absolute_percentage_error: 82.5243 - val_loss: 1.2772 - val_mean_absolute_error: 0.8882 - val_mean_absolute_percentage_error: 41.8911
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6985 - mean_absolute_error: 1.3702 - mean_absolute_percentage_error: 64.4007 - val_loss: 1.2904 - val_mean_absolute_error: 0.8992 - val_mean_absolute_percentage_error: 42.9246
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3999 - mean_absolute_error: 1.4563 - mean_absolute_percentage_error: 80.6454 - val_loss: 1.2369 - val_mean_absolute_error: 0.8678 - val_mean_absolute_percentage_error: 40.4647
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8921 - mean_absolute_error: 1.3803 - mean_absolute_percentage_error: 64.9422 - val_loss: 1.2204 - val_mean_absolute_error: 0.8478 - val_mean_absolute_percentage_error: 38.2493
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0332 - mean_absolute_error: 1.3535 - mean_absolute_percentage_error: 63.8303 - val_loss: 1.3198 - val_mean_absolute_error: 0.8804 - val_mean_absolute_percentage_error: 37.8096
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5890 - mean_absolute_error: 1.4892 - mean_absolute_percentage_error: 76.5193 - val_loss: 1.2489 - val_mean_absolute_error: 0.8862 - val_mean_absolute_percentage_error: 42.5534
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5868 - mean_absolute_error: 1.4056 - mean_absolute_percentage_error: 74.8035 - val_loss: 1.2219 - val_mean_absolute_error: 0.8725 - val_mean_absolute_percentage_error: 41.6158
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2959 - mean_absolute_error: 1.4033 - mean_absolute_percentage_error: 64.6416 - val_loss: 1.1783 - val_mean_absolute_error: 0.8378 - val_mean_absolute_percentage_error: 38.4484
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1354 - mean_absolute_error: 1.4139 - mean_absolute_percentage_error: 69.0070 - val_loss: 1.1696 - val_mean_absolute_error: 0.8342 - val_mean_absolute_percentage_error: 38.2502
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9428 - mean_absolute_error: 1.3099 - mean_absolute_percentage_error: 69.5695 - val_loss: 1.1595 - val_mean_absolute_error: 0.8300 - val_mean_absolute_percentage_error: 38.0335
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6859 - mean_absolute_error: 1.2460 - mean_absolute_percentage_error: 61.2701 - val_loss: 1.1552 - val_mean_absolute_error: 0.8380 - val_mean_absolute_percentage_error: 39.3219
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6635 - mean_absolute_error: 1.5078 - mean_absolute_percentage_error: 74.6333 - val_loss: 1.1401 - val_mean_absolute_error: 0.8263 - val_mean_absolute_percentage_error: 38.2788
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2599 - mean_absolute_error: 1.1679 - mean_absolute_percentage_error: 55.8524 - val_loss: 1.1442 - val_mean_absolute_error: 0.8164 - val_mean_absolute_percentage_error: 36.7923
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0746 - mean_absolute_error: 1.3481 - mean_absolute_percentage_error: 62.9645 - val_loss: 1.1329 - val_mean_absolute_error: 0.8129 - val_mean_absolute_percentage_error: 36.7322
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8076 - mean_absolute_error: 1.2627 - mean_absolute_percentage_error: 64.2564 - val_loss: 1.1329 - val_mean_absolute_error: 0.8113 - val_mean_absolute_percentage_error: 36.4308
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3598 - mean_absolute_error: 1.1814 - mean_absolute_percentage_error: 66.1617 - val_loss: 1.1032 - val_mean_absolute_error: 0.8107 - val_mean_absolute_percentage_error: 37.4409
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8021 - mean_absolute_error: 1.2381 - mean_absolute_percentage_error: 59.2650 - val_loss: 1.0963 - val_mean_absolute_error: 0.8084 - val_mean_absolute_percentage_error: 37.3773
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4208 - mean_absolute_error: 1.3073 - mean_absolute_percentage_error: 67.5122 - val_loss: 1.0896 - val_mean_absolute_error: 0.8113 - val_mean_absolute_percentage_error: 38.1026
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0193 - mean_absolute_error: 1.2211 - mean_absolute_percentage_error: 57.6880 - val_loss: 1.2013 - val_mean_absolute_error: 0.8438 - val_mean_absolute_percentage_error: 36.4385
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7961 - mean_absolute_error: 1.2132 - mean_absolute_percentage_error: 88.0875 - val_loss: 1.0790 - val_mean_absolute_error: 0.7951 - val_mean_absolute_percentage_error: 36.2984
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2370 - mean_absolute_error: 1.1793 - mean_absolute_percentage_error: 61.0010 - val_loss: 1.0704 - val_mean_absolute_error: 0.7917 - val_mean_absolute_percentage_error: 36.1685
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0719 - mean_absolute_error: 1.1136 - mean_absolute_percentage_error: 63.4327 - val_loss: 1.0870 - val_mean_absolute_error: 0.7939 - val_mean_absolute_percentage_error: 35.5560
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2524 - mean_absolute_error: 1.1563 - mean_absolute_percentage_error: 68.6132 - val_loss: 1.0490 - val_mean_absolute_error: 0.7859 - val_mean_absolute_percentage_error: 36.1688
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7917 - mean_absolute_error: 1.1745 - mean_absolute_percentage_error: 57.5170 - val_loss: 1.0997 - val_mean_absolute_error: 0.8001 - val_mean_absolute_percentage_error: 35.3895
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9333 - mean_absolute_error: 1.0871 - mean_absolute_percentage_error: 55.6681 - val_loss: 1.0693 - val_mean_absolute_error: 0.7877 - val_mean_absolute_percentage_error: 35.2682
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1541 - mean_absolute_error: 1.0808 - mean_absolute_percentage_error: 61.6306 - val_loss: 1.0199 - val_mean_absolute_error: 0.7915 - val_mean_absolute_percentage_error: 38.0363
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1825 - mean_absolute_error: 1.0833 - mean_absolute_percentage_error: 54.7454 - val_loss: 1.0133 - val_mean_absolute_error: 0.7763 - val_mean_absolute_percentage_error: 36.2120
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9007 - mean_absolute_error: 1.1588 - mean_absolute_percentage_error: 74.8317 - val_loss: 1.0536 - val_mean_absolute_error: 0.7830 - val_mean_absolute_percentage_error: 35.0564
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6186 - mean_absolute_error: 1.1745 - mean_absolute_percentage_error: 62.7696 - val_loss: 1.0048 - val_mean_absolute_error: 0.7697 - val_mean_absolute_percentage_error: 35.6251
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5048 - mean_absolute_error: 1.1438 - mean_absolute_percentage_error: 63.8989 - val_loss: 1.0434 - val_mean_absolute_error: 0.7806 - val_mean_absolute_percentage_error: 34.9273
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1875 - mean_absolute_error: 1.1055 - mean_absolute_percentage_error: 58.4458 - val_loss: 0.9783 - val_mean_absolute_error: 0.7670 - val_mean_absolute_percentage_error: 36.2682
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1925 - mean_absolute_error: 1.1152 - mean_absolute_percentage_error: 58.4702 - val_loss: 0.9832 - val_mean_absolute_error: 0.7614 - val_mean_absolute_percentage_error: 35.2728
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1213 - mean_absolute_error: 1.1119 - mean_absolute_percentage_error: 51.4510 - val_loss: 0.9855 - val_mean_absolute_error: 0.7604 - val_mean_absolute_percentage_error: 34.9037
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9001 - mean_absolute_error: 1.0840 - mean_absolute_percentage_error: 78.6783 - val_loss: 1.0006 - val_mean_absolute_error: 0.7656 - val_mean_absolute_percentage_error: 34.6259
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1197 - mean_absolute_error: 1.1022 - mean_absolute_percentage_error: 52.8119 - val_loss: 0.9497 - val_mean_absolute_error: 0.7521 - val_mean_absolute_percentage_error: 35.4238
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9249 - mean_absolute_error: 1.0382 - mean_absolute_percentage_error: 66.3984 - val_loss: 0.9637 - val_mean_absolute_error: 0.7533 - val_mean_absolute_percentage_error: 34.7465
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8101 - mean_absolute_error: 1.0211 - mean_absolute_percentage_error: 56.7541 - val_loss: 0.9488 - val_mean_absolute_error: 0.7488 - val_mean_absolute_percentage_error: 34.8147
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0400 - mean_absolute_error: 1.0632 - mean_absolute_percentage_error: 59.7077 - val_loss: 0.9196 - val_mean_absolute_error: 0.7499 - val_mean_absolute_percentage_error: 36.3008
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9020 - mean_absolute_error: 1.0144 - mean_absolute_percentage_error: 49.7549 - val_loss: 0.9317 - val_mean_absolute_error: 0.7428 - val_mean_absolute_percentage_error: 34.6735
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5922 - mean_absolute_error: 0.9998 - mean_absolute_percentage_error: 50.0087 - val_loss: 0.9178 - val_mean_absolute_error: 0.7387 - val_mean_absolute_percentage_error: 34.7887
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7925 - mean_absolute_error: 1.0032 - mean_absolute_percentage_error: 53.6810 - val_loss: 0.9137 - val_mean_absolute_error: 0.7367 - val_mean_absolute_percentage_error: 34.6296
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0500 - mean_absolute_error: 1.0160 - mean_absolute_percentage_error: 52.5689 - val_loss: 0.8898 - val_mean_absolute_error: 0.7401 - val_mean_absolute_percentage_error: 36.2086
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2407 - mean_absolute_error: 1.0620 - mean_absolute_percentage_error: 53.3264 - val_loss: 0.8837 - val_mean_absolute_error: 0.7419 - val_mean_absolute_percentage_error: 36.7015
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7965 - mean_absolute_error: 1.0077 - mean_absolute_percentage_error: 65.2554 - val_loss: 0.8759 - val_mean_absolute_error: 0.7304 - val_mean_absolute_percentage_error: 35.5440
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9503 - mean_absolute_error: 1.0308 - mean_absolute_percentage_error: 75.4110 - val_loss: 0.8869 - val_mean_absolute_error: 0.7275 - val_mean_absolute_percentage_error: 34.3725
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9534 - mean_absolute_error: 1.0315 - mean_absolute_percentage_error: 49.8465 - val_loss: 0.8611 - val_mean_absolute_error: 0.7279 - val_mean_absolute_percentage_error: 35.7936
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7155 - mean_absolute_error: 0.9755 - mean_absolute_percentage_error: 48.9372 - val_loss: 0.8538 - val_mean_absolute_error: 0.7228 - val_mean_absolute_percentage_error: 35.4640
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8883 - mean_absolute_error: 1.0285 - mean_absolute_percentage_error: 57.7718 - val_loss: 0.8474 - val_mean_absolute_error: 0.7217 - val_mean_absolute_percentage_error: 35.5692
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2140 - mean_absolute_error: 1.0184 - mean_absolute_percentage_error: 51.8132 - val_loss: 0.8413 - val_mean_absolute_error: 0.7222 - val_mean_absolute_percentage_error: 35.8489
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5015 - mean_absolute_error: 1.0128 - mean_absolute_percentage_error: 53.1206 - val_loss: 0.8370 - val_mean_absolute_error: 0.7134 - val_mean_absolute_percentage_error: 34.8689

# %%
model.evaluate(x_test,y_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.7447 - mean_absolute_error: 0.6766 - mean_absolute_percentage_error: 34.0639
# [0.837027907371521, 0.7133901119232178, 34.8688850402832]

# %%
preds = model.predict(x_test)
preds.size
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 211

# %%
a, x_test2, b , y_test2 = train_test_split(x,y,test_size=0.8,random_state=42)

# %%
preds2 = model.predict(x_test2)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step

# %%
from sklearn.metrics import mean_absolute_error

sn = mean_absolute_error(preds2,y_test2)

print(sn)
# Out:
# 0.7886352662719079
